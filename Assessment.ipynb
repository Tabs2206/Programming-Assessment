# %% [markdown]
# #Programming Assessment
# ## Clean Transportation Program

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Clean_Transportation_Program.csv')
dataset
# Out:
#                  X             Y  OBJECTID  Num  ARFVTP_ID Agreement_Number  \
# 0    -1.362841e+07  4.545297e+06      7676  NaN        NaN       ARV-10-032
# 1    -1.357900e+07  4.516520e+06      7677  NaN        NaN       ARV-13-032
# 2    -1.302918e+07  3.861707e+06      7678  NaN        NaN       ARV-12-015
# 3    -1.302064e+07  3.868231e+06      7679  NaN        NaN       ARV-09-005
# 4    -1.375223e+07  5.056974e+06      7680  NaN        NaN       ARV-22-008
# ...            ...           ...       ...  ...        ...              ...
# 2733           NaN           NaN     10409  NaN        NaN       ZVI-21-007
# 2734           NaN           NaN     10410  NaN        NaN       GFO-21-601
# 2735           NaN           NaN     10411  NaN        NaN       ZVI-22-035
# 2736           NaN           NaN     10412  NaN        NaN       ZVI-21-004
# 2737           NaN           NaN     10413  NaN        NaN       ARV-22-002
#
#      Project_Number              Recipient_Contractor  \
# ...
